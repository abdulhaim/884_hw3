# %% [markdown]
# # 6.884 HW3 Solution | Marwa Abdulhai

# %% [markdown]
# ## Problem 1: Learning a policy with Behavioral Cloning

# %% [markdown]
# In this problem, we will learn a policy for pushing using the expert dataset. We will use the learned policy for pushing an object.
#
# Deliverables:
#
# • Source code used for learning policy with behavioral cloning (20 pts).
#
# To run training script, run `main.py `. This is where source code is found.

# %% [markdown]
# • A detailed description of policy architecture and loss function used for training (5 pts).
#
# `Model(
#   (fc1): Linear(in_features=9, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=2, bias=True)
#   (mse): MSELoss()
# )`

# %%
• Training plot showing loss as a function of time. Evaluate the learned policy on 100 episodes and report the average L2 distance between the object location and the goal location. An average L2 distance of 0.22 (or less) should be good (15 pts).
# Out:
#   File "<ipython-input-13-5bf96622d46e>", line 1
#     • Training plot showing loss as a function of time. Evaluate the learned policy on 100 episodes and report the average L2 distance between the object location and the goal location. An average L2 distance of 0.22 (or less) should be good (15 pts).
#     ^
# SyntaxError: invalid character in identifier

# %%
from IPython.display import Image
Image(filename='plots/cloning.png')

# %% [markdown]
# Average L2 Distance: 0.22071737051150697

# %% [markdown]
# • Video showing evaluation of policy on 10 episodes. (10 pts).

# %% [markdown]
# Video in videos called `videos/behavior_cloning.avi`. You will need to play via VLC (as it doesnt work on QuickTime).

# %% [markdown]
# ## Problem 2: Fine-tuning with Reinforcement Learning

# %% [markdown]
# In this problem, we will fine-tune the policy learned using the expert dataset with PPO. You can use your imple- mentation from HW1.
# To ensure that we don’t stray too far from the expert demonstrations, we can modify the PPO objective function to include λE(s,a)∼expert[logπθ(a|s)] where πθ is the policy being fine-tuned and λ is a hyper-parameter. Compare the joint loss fine-tuning to the vanilla fine-tuning where λ = 0.
# Once you have fine-tuned the policy, you should learn another policy from scratch and compare its learning curve to that of the fine-tuned policy.
#
# Deliverables:
#
# • Source code used for fine-tuning the learned policy and learning a policy from scratch (20 pts).
#
# To run training script, run `fine_tuning.py `.  Source code for all three versions found here, and there are 3 separate functions in `ppo.py` for each of the methods.

# %% [markdown]
# • Learning curve of the vanilla fine-tuned policy, joint loss fine-tuned policy and the policy learned form scratch. Evaluate the three policies on 100 episodes and report the average L2 distance between the object location and the goal location (20 pts).

# %%
from IPython.display import Image
Image(filename='plots/scratch.png')

# %% [markdown]
# Average L2 Distance:  0.383072777813324

# %%
from IPython.display import Image
Image(filename='plots/vanilla.png')

# %% [markdown]
# Average L2 Distance: 0.3273400376110899

# %%
from IPython.display import Image
Image(filename='plots/joint.png')

# %% [markdown]
# Average L2 Distance: 0.3585434422161567

# %% [markdown]
# • Video showing evaluation of the three policies on 10 episodes (10 pts).

# %% [markdown]
# Video in videos called `videos/scratch.avi`, `videos/vanilla.avi`, `videos/joint_loss.avi`. You will need to play via VLC (as it doesnt work on QuickTime)

# %% [markdown]
# We see that the vanilla fine tune and joint loss converge more quickly than ppo trained from scratch, and hence I did not have to run it for so many episodes.
